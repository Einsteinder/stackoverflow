# %%
import numpy as np
import pandas
from matplotlib import cm
from matplotlib import pyplot as plt
from matplotlib.pyplot import yticks
import chart_studio.plotly as py
from plotly.graph_objs import *
import seaborn as sns
from collections import Counter

# %matplotlib inline

df = pandas.read_csv('developer_survey_2019/survey_results_public.csv')
schema = pandas.read_csv('developer_survey_2019/survey_results_schema.csv').set_index('Column')

# %%
plt.subplots(figsize=(15,35))
sns.countplot(y = df.Country, order = df.Country.value_counts().index)

# %%
"""
first 5 countries and China: 
United States                            20949
India                                     9061
Germany                                   5866
United Kingdom                            5737
Canada                                    3395
China                                      664 
"""
       
df.Country.value_counts()
# Out:
# United States                            20949
# India                                     9061
# Germany                                   5866
# United Kingdom                            5737
# Canada                                    3395
# France                                    2391
# Brazil                                    1948
# Poland                                    1922
# Australia                                 1903
# Netherlands                               1852
# Russian Federation                        1694
# Spain                                     1604
# Italy                                     1576
# Sweden                                    1274
# Switzerland                                978
# Israel                                     952
# Turkey                                     949
# Pakistan                                   923
# Ukraine                                    868
# Austria                                    839
# Czech Republic                             764
# Romania                                    760
# Iran                                       738
# Belgium                                    727
# China                                      664
# Bulgaria                                   659
# Mexico                                     642
# South Africa                               627
# Denmark                                    617
# Bangladesh                                 605
#                                          ...
# Belize                                       3
# Guyana                                       3
# Liechtenstein                                3
# Cape Verde                                   3
# Burundi                                      3
# Bahamas                                      3
# Democratic People's Republic of Korea        3
# Barbados                                     3
# Guinea                                       3
# Mali                                         3
# Lao People's Democratic Republic             3
# Liberia                                      2
# Bhutan                                       2
# Malawi                                       2
# Djibouti                                     2
# Sierra Leone                                 2
# Seychelles                                   2
# Gabon                                        2
# San Marino                                   2
# Timor-Leste                                  1
# Tonga                                        1
# Niger                                        1
# Brunei Darussalam                            1
# Papua New Guinea                             1
# Sao Tome and Principe                        1
# Chad                                         1
# North Korea                                  1
# Saint Kitts and Nevis                        1
# Saint Vincent and the Grenadines             1
# Dominica                                     1
# Name: Country, Length: 179, dtype: int64

# %%
countries_of_interest = ['United States','India','Germany','United Kingdom','Canada','China']

# %%
df.CareerSat.unique()
# Out:
# array([nan, 'Slightly satisfied', 'Very satisfied', 'Very dissatisfied',
#        'Slightly dissatisfied', 'Neither satisfied nor dissatisfied'],
#       dtype=object)

# %%
CareerSat = df.CareerSat.dropna()

# %%
CareerSat.unique()
# Out:
# array(['Slightly satisfied', 'Very satisfied', 'Very dissatisfied',
#        'Slightly dissatisfied', 'Neither satisfied nor dissatisfied'],
#       dtype=object)

# %%
def to_satisfied_value(label):
    sat_map = {  
        'Very dissatisfied': 0,
        'Slightly dissatisfied': 1, 
        'Neither satisfied nor dissatisfied': 2, 
        'Slightly satisfied': 3, 
        'Very satisfied': 4
              }
    return sat_map[label]

# %%
carrer_sat_df = pandas.DataFrame(countries_of_interest, columns=['Country'])

# %%
carrer_sat_df['CareerSat'] = carrer_sat_df['Country'].apply(
    lambda c: df[df['Country'] == c]['CareerSat'].dropna().apply(to_satisfied_value).mean())

# %%
carrer_sat_df
# Out:
#           Country  CareerSat
# 0   United States   3.195966
# 1           India   2.707324
# 2         Germany   2.930087
# 3  United Kingdom   3.052311
# 4          Canada   3.110791
# 5           China   2.169697

# %%
coi_df = df[df['Country'].map(lambda x: x in countries_of_interest)]
coi_df = coi_df.dropna(subset=['JobSat', 'CareerSat'])
coi_df['JobSat'] = coi_df['JobSat'].apply(to_satisfied_value)
coi_df['CareerSat']=coi_df['CareerSat'].apply(to_satisfied_value)

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(x="Country", y="JobSat", data=coi_df)
fig = plt.figure(figsize=(8,6))
sns.boxplot(x="Country", y="CareerSat", data=coi_df)

# %%
coi_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 3               4                     I am a developer by profession       No
# 5               6  I am not primarily a developer, but I write co...      Yes
# 9              10                     I am a developer by profession      Yes
# 12             13                     I am a developer by profession      Yes
# 13             14                     I am a developer by profession      Yes
# 15             16                     I am a developer by profession      Yes
# 21             22                     I am a developer by profession      Yes
# 22             23                     I am a developer by profession      Yes
# 25             26                     I am a developer by profession      Yes
# 28             29                     I am a developer by profession      Yes
# 31             32                     I am a developer by profession       No
# 34             35                     I am a developer by profession       No
# 35             36                     I am a developer by profession      Yes
# 38             39                     I am a developer by profession      Yes
# 43             44                     I am a developer by profession      Yes
# 44             45  I am not primarily a developer, but I write co...      Yes
# 45             46                     I am a developer by profession      Yes
# 46             47                     I am a developer by profession      Yes
# 49             50                     I am a developer by profession      Yes
# 52             53  I am not primarily a developer, but I write co...      Yes
# 55             56                     I am a developer by profession       No
# 57             58                     I am a developer by profession      Yes
# 59             60                     I am a developer by profession      Yes
# 60             61                     I am a developer by profession      Yes
# 64             65                     I am a developer by profession      Yes
# 65             66                     I am a developer by profession      Yes
# 67             68                     I am a developer by profession      Yes
# 69             70                     I am a developer by profession       No
# 74             75                     I am a developer by profession      Yes
# 75             76                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 88273       88825                     I am a developer by profession      Yes
# 88274       88826                     I am a developer by profession      Yes
# 88275       88827                     I am a developer by profession      Yes
# 88278       88830                     I am a developer by profession      Yes
# 88281       88833                     I am a developer by profession      Yes
# 88282       88834                     I am a developer by profession      Yes
# 88283       88835                     I am a developer by profession      Yes
# 88287       88839                     I am a developer by profession      Yes
# 88289       88841                     I am a developer by profession      Yes
# 88290       88842                     I am a developer by profession      Yes
# 88291       88843                     I am a developer by profession      Yes
# 88293       88845                     I am a developer by profession      Yes
# 88298       88850                     I am a developer by profession      Yes
# 88301       88853                     I am a developer by profession      Yes
# 88302       88854                     I am a developer by profession      Yes
# 88303       88855                     I am a developer by profession      Yes
# 88304       88856                     I am a developer by profession      Yes
# 88305       88857                     I am a developer by profession      Yes
# 88306       88858                     I am a developer by profession      Yes
# 88309       88861  I am not primarily a developer, but I write co...       No
# 88312       88865                     I am a developer by profession       No
# 88315       88868                     I am a developer by profession      Yes
# 88316       88869                     I am a developer by profession       No
# 88319       88872                     I am a developer by profession      Yes
# 88320       88873                     I am a developer by profession      Yes
# 88321       88874                     I am a developer by profession      Yes
# 88323       88876                     I am a developer by profession      Yes
# 88324       88877                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
# 88327       88880  I am not primarily a developer, but I write co...      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 5                                                  Never
# 9                             Once a month or more often
# 12     Less than once a month but more than once per ...
# 13                               Less than once per year
# 15                                                 Never
# 21                               Less than once per year
# 22                               Less than once per year
# 25                               Less than once per year
# 28     Less than once a month but more than once per ...
# 31                                                 Never
# 34                                                 Never
# 35     Less than once a month but more than once per ...
# 38                               Less than once per year
# 43                            Once a month or more often
# 44                                                 Never
# 45                               Less than once per year
# 46                               Less than once per year
# 49                            Once a month or more often
# 52     Less than once a month but more than once per ...
# 55                                                 Never
# 57                            Once a month or more often
# 59     Less than once a month but more than once per ...
# 60                               Less than once per year
# 64                                                 Never
# 65                            Once a month or more often
# 67     Less than once a month but more than once per ...
# 69                               Less than once per year
# 74                                                 Never
# 75                                                 Never
# ...                                                  ...
# 88273                                              Never
# 88274                            Less than once per year
# 88275                            Less than once per year
# 88278                                              Never
# 88281  Less than once a month but more than once per ...
# 88282                         Once a month or more often
# 88283  Less than once a month but more than once per ...
# 88287                            Less than once per year
# 88289                                              Never
# 88290  Less than once a month but more than once per ...
# 88291                                              Never
# 88293                         Once a month or more often
# 88298                                              Never
# 88301                            Less than once per year
# 88302                                              Never
# 88303                                              Never
# 88304                                              Never
# 88305                            Less than once per year
# 88306  Less than once a month but more than once per ...
# 88309  Less than once a month but more than once per ...
# 88312  Less than once a month but more than once per ...
# 88315                         Once a month or more often
# 88316                                              Never
# 88319  Less than once a month but more than once per ...
# 88320  Less than once a month but more than once per ...
# 88321                         Once a month or more often
# 88323                                              Never
# 88324                            Less than once per year
# 88325                            Less than once per year
# 88327                                              Never
#
#                                               OpenSource  \
# 3      The quality of OSS and closed source software ...
# 5      The quality of OSS and closed source software ...
# 9      OSS is, on average, of HIGHER quality than pro...
# 12     OSS is, on average, of HIGHER quality than pro...
# 13     The quality of OSS and closed source software ...
# 15     The quality of OSS and closed source software ...
# 21     OSS is, on average, of HIGHER quality than pro...
# 22     The quality of OSS and closed source software ...
# 25     The quality of OSS and closed source software ...
# 28     OSS is, on average, of HIGHER quality than pro...
# 31     The quality of OSS and closed source software ...
# 34     OSS is, on average, of HIGHER quality than pro...
# 35     The quality of OSS and closed source software ...
# 38     The quality of OSS and closed source software ...
# 43     The quality of OSS and closed source software ...
# 44     The quality of OSS and closed source software ...
# 45     OSS is, on average, of HIGHER quality than pro...
# 46     OSS is, on average, of HIGHER quality than pro...
# 49     OSS is, on average, of LOWER quality than prop...
# 52     OSS is, on average, of HIGHER quality than pro...
# 55     The quality of OSS and closed source software ...
# 57     OSS is, on average, of LOWER quality than prop...
# 59     OSS is, on average, of HIGHER quality than pro...
# 60     OSS is, on average, of LOWER quality than prop...
# 64                                                   NaN
# 65     OSS is, on average, of HIGHER quality than pro...
# 67     OSS is, on average, of LOWER quality than prop...
# 69     The quality of OSS and closed source software ...
# 74     OSS is, on average, of HIGHER quality than pro...
# 75     The quality of OSS and closed source software ...
# ...                                                  ...
# 88273  OSS is, on average, of LOWER quality than prop...
# 88274  The quality of OSS and closed source software ...
# 88275  The quality of OSS and closed source software ...
# 88278  OSS is, on average, of HIGHER quality than pro...
# 88281  The quality of OSS and closed source software ...
# 88282  OSS is, on average, of HIGHER quality than pro...
# 88283  OSS is, on average, of HIGHER quality than pro...
# 88287  OSS is, on average, of HIGHER quality than pro...
# 88289  OSS is, on average, of HIGHER quality than pro...
# 88290  The quality of OSS and closed source software ...
# 88291  OSS is, on average, of HIGHER quality than pro...
# 88293  OSS is, on average, of HIGHER quality than pro...
# 88298  OSS is, on average, of HIGHER quality than pro...
# 88301  OSS is, on average, of HIGHER quality than pro...
# 88302  OSS is, on average, of HIGHER quality than pro...
# 88303  The quality of OSS and closed source software ...
# 88304  OSS is, on average, of HIGHER quality than pro...
# 88305  The quality of OSS and closed source software ...
# 88306  The quality of OSS and closed source software ...
# 88309  The quality of OSS and closed source software ...
# 88312  The quality of OSS and closed source software ...
# 88315  OSS is, on average, of HIGHER quality than pro...
# 88316  OSS is, on average, of LOWER quality than prop...
# 88319  OSS is, on average, of HIGHER quality than pro...
# 88320  The quality of OSS and closed source software ...
# 88321  OSS is, on average, of LOWER quality than prop...
# 88323  OSS is, on average, of HIGHER quality than pro...
# 88324  OSS is, on average, of HIGHER quality than pro...
# 88325  The quality of OSS and closed source software ...
# 88327  The quality of OSS and closed source software ...
#
#                                               Employment         Country  \
# 3                                     Employed full-time   United States
# 5                                     Employed full-time          Canada
# 9                                     Employed full-time           India
# 12                                    Employed full-time   United States
# 13                                    Employed full-time         Germany
# 15                                    Employed full-time  United Kingdom
# 21                                    Employed full-time   United States
# 22                                    Employed full-time   United States
# 25                                    Employed full-time   United States
# 28                                    Employed full-time   United States
# 31                                    Employed full-time   United States
# 34                                    Employed full-time   United States
# 35                                    Employed full-time         Germany
# 38                                    Employed full-time   United States
# 43                                    Employed full-time         Germany
# 44                                    Employed full-time   United States
# 45     Independent contractor, freelancer, or self-em...   United States
# 46                                    Employed full-time   United States
# 49                                    Employed full-time           India
# 52                                    Employed full-time   United States
# 55                                    Employed full-time           China
# 57                                    Employed full-time   United States
# 59                                    Employed full-time   United States
# 60                                    Employed full-time   United States
# 64                                    Employed full-time           India
# 65                                    Employed full-time         Germany
# 67                                    Employed full-time           India
# 69                                    Employed full-time   United States
# 74                                    Employed full-time           India
# 75                                    Employed full-time  United Kingdom
# ...                                                  ...             ...
# 88273                                 Employed full-time           India
# 88274  Independent contractor, freelancer, or self-em...   United States
# 88275                                 Employed full-time   United States
# 88278                                 Employed full-time   United States
# 88281  Independent contractor, freelancer, or self-em...  United Kingdom
# 88282                                 Employed full-time   United States
# 88283                                 Employed full-time   United States
# 88287  Independent contractor, freelancer, or self-em...   United States
# 88289                                 Employed full-time          Canada
# 88290                                 Employed full-time   United States
# 88291                                 Employed full-time           India
# 88293                                 Employed full-time          Canada
# 88298                                 Employed full-time   United States
# 88301                                 Employed full-time   United States
# 88302                                 Employed full-time          Canada
# 88303                                 Employed full-time   United States
# 88304                                 Employed full-time           India
# 88305  Independent contractor, freelancer, or self-em...   United States
# 88306                                 Employed full-time          Canada
# 88309                                 Employed full-time         Germany
# 88312                                 Employed full-time   United States
# 88315                                 Employed full-time         Germany
# 88316                                 Employed full-time           India
# 88319                                 Employed full-time           India
# 88320  Independent contractor, freelancer, or self-em...          Canada
# 88321                                 Employed full-time   United States
# 88323                                 Employed full-time   United States
# 88324                                 Employed full-time   United States
# 88325                                 Employed full-time   United States
# 88327                                 Employed full-time   United States
#
#               Student                                            EdLevel  \
# 3                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                  No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9                  No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 12                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 13                 No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 15                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 21                 No  Some college/university study without earning ...
# 22                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 25                 No  Some college/university study without earning ...
# 28                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 31                 No                                   Associate degree
# 34                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 35     Yes, full-time  Secondary school (e.g. American high school, G...
# 38                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 43                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 44                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 45                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 46                 No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 49                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 52     Yes, full-time  Secondary school (e.g. American high school, G...
# 55                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 57                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 59                 No  Secondary school (e.g. American high school, G...
# 60                 No  Some college/university study without earning ...
# 64                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 65                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 67                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 69                 No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 74     Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 75                 No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...                                                ...
# 88273  Yes, full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88274              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88275              No  Some college/university study without earning ...
# 88278              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88281              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88282              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88283              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88287              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88289              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88290              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88291              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88293              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88298              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88301              No  Some college/university study without earning ...
# 88302              No  Some college/university study without earning ...
# 88303              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88304  Yes, full-time        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88305              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88306              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88309              No  Secondary school (e.g. American high school, G...
# 88312              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88315              No  Some college/university study without earning ...
# 88316             NaN                                                NaN
# 88319              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88320              No  Some college/university study without earning ...
# 88321              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88323              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88324              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88325              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88327              No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  ...  \
# 3      Computer science, computer engineering, or sof...  ...
# 5                              Mathematics or statistics  ...
# 9                                                    NaN  ...
# 12     Computer science, computer engineering, or sof...  ...
# 13     Computer science, computer engineering, or sof...  ...
# 15                                                   NaN  ...
# 21                                                   NaN  ...
# 22     Information systems, information technology, o...  ...
# 25     Computer science, computer engineering, or sof...  ...
# 28                                                   NaN  ...
# 31     Information systems, information technology, o...  ...
# 34     Information systems, information technology, o...  ...
# 35                                                   NaN  ...
# 38     Computer science, computer engineering, or sof...  ...
# 43     Information systems, information technology, o...  ...
# 44     Another engineering discipline (ex. civil, ele...  ...
# 45     Another engineering discipline (ex. civil, ele...  ...
# 46     A humanities discipline (ex. literature, histo...  ...
# 49     Another engineering discipline (ex. civil, ele...  ...
# 52                                                   NaN  ...
# 55     Information systems, information technology, o...  ...
# 57     Computer science, computer engineering, or sof...  ...
# 59                                                   NaN  ...
# 60     Computer science, computer engineering, or sof...  ...
# 64     Information systems, information technology, o...  ...
# 65     Computer science, computer engineering, or sof...  ...
# 67                         Web development or web design  ...
# 69     Information systems, information technology, o...  ...
# 74     Computer science, computer engineering, or sof...  ...
# 75     Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 88273  Another engineering discipline (ex. civil, ele...  ...
# 88274  Computer science, computer engineering, or sof...  ...
# 88275  Computer science, computer engineering, or sof...  ...
# 88278  A natural science (ex. biology, chemistry, phy...  ...
# 88281                                                NaN  ...
# 88282  Computer science, computer engineering, or sof...  ...
# 88283  Computer science, computer engineering, or sof...  ...
# 88287  Fine arts or performing arts (ex. graphic desi...  ...
# 88289  Computer science, computer engineering, or sof...  ...
# 88290  Computer science, computer engineering, or sof...  ...
# 88291  Computer science, computer engineering, or sof...  ...
# 88293  A natural science (ex. biology, chemistry, phy...  ...
# 88298  Computer science, computer engineering, or sof...  ...
# 88301  Computer science, computer engineering, or sof...  ...
# 88302  Computer science, computer engineering, or sof...  ...
# 88303  Computer science, computer engineering, or sof...  ...
# 88304                      Web development or web design  ...
# 88305  Computer science, computer engineering, or sof...  ...
# 88306  Computer science, computer engineering, or sof...  ...
# 88309                                                NaN  ...
# 88312  A social science (ex. anthropology, psychology...  ...
# 88315                      Web development or web design  ...
# 88316                                                NaN  ...
# 88319  Computer science, computer engineering, or sof...  ...
# 88320  Computer science, computer engineering, or sof...  ...
# 88321  A social science (ex. anthropology, psychology...  ...
# 88323  Computer science, computer engineering, or sof...  ...
# 88324  Computer science, computer engineering, or sof...  ...
# 88325  Computer science, computer engineering, or sof...  ...
# 88327  Computer science, computer engineering, or sof...  ...
#
#                                            WelcomeChange  \
# 3                Just as welcome now as I felt last year
# 5                Just as welcome now as I felt last year
# 9               Somewhat less welcome now than last year
# 12              Somewhat more welcome now than last year
# 13               Just as welcome now as I felt last year
# 15               Just as welcome now as I felt last year
# 21               Just as welcome now as I felt last year
# 22               Just as welcome now as I felt last year
# 25               Just as welcome now as I felt last year
# 28               Just as welcome now as I felt last year
# 31              Somewhat more welcome now than last year
# 34               Just as welcome now as I felt last year
# 35              Somewhat less welcome now than last year
# 38              Somewhat less welcome now than last year
# 43               Just as welcome now as I felt last year
# 44     Not applicable - I did not use Stack Overflow ...
# 45               Just as welcome now as I felt last year
# 46               Just as welcome now as I felt last year
# 49               Just as welcome now as I felt last year
# 52              Somewhat more welcome now than last year
# 55               Just as welcome now as I felt last year
# 57               Just as welcome now as I felt last year
# 59                                                   NaN
# 60                 A lot more welcome now than last year
# 64                 A lot more welcome now than last year
# 65               Just as welcome now as I felt last year
# 67              Somewhat more welcome now than last year
# 69               Just as welcome now as I felt last year
# 74               Just as welcome now as I felt last year
# 75               Just as welcome now as I felt last year
# ...                                                  ...
# 88273           Somewhat less welcome now than last year
# 88274            Just as welcome now as I felt last year
# 88275            Just as welcome now as I felt last year
# 88278            Just as welcome now as I felt last year
# 88281            Just as welcome now as I felt last year
# 88282            Just as welcome now as I felt last year
# 88283            Just as welcome now as I felt last year
# 88287            Just as welcome now as I felt last year
# 88289            Just as welcome now as I felt last year
# 88290            Just as welcome now as I felt last year
# 88291           Somewhat more welcome now than last year
# 88293           Somewhat more welcome now than last year
# 88298           Somewhat less welcome now than last year
# 88301            Just as welcome now as I felt last year
# 88302            Just as welcome now as I felt last year
# 88303            Just as welcome now as I felt last year
# 88304           Somewhat less welcome now than last year
# 88305              A lot more welcome now than last year
# 88306            Just as welcome now as I felt last year
# 88309            Just as welcome now as I felt last year
# 88312            Just as welcome now as I felt last year
# 88315           Somewhat more welcome now than last year
# 88316              A lot more welcome now than last year
# 88319           Somewhat more welcome now than last year
# 88320            Just as welcome now as I felt last year
# 88321            Just as welcome now as I felt last year
# 88323              A lot less welcome now than last year
# 88324           Somewhat more welcome now than last year
# 88325            Just as welcome now as I felt last year
# 88327                                                NaN
#
#                                             SONewContent   Age Gender Trans  \
# 3      Tech articles written by other developers;Indu...  22.0    Man    No
# 5      Tech articles written by other developers;Indu...  28.0    Man    No
# 9      Tech articles written by other developers;Tech...   NaN    NaN   NaN
# 12     Tech articles written by other developers;Cour...  28.0    Man    No
# 13     Tech articles written by other developers;Cour...  31.0    Man    No
# 15     Tech articles written by other developers;Indu...  26.0    Man    No
# 21     Tech articles written by other developers;Indu...  47.0    Man    No
# 22     Tech articles written by other developers;Tech...  22.0    Man    No
# 25                                                   NaN  34.0    Man    No
# 28     Tech articles written by other developers;Cour...  32.0    Man    No
# 31     Tech articles written by other developers;Indu...  21.0    Man    No
# 34     Tech articles written by other developers;Indu...  35.0  Woman    No
# 35                                                   NaN  21.0    Man    No
# 38             Tech articles written by other developers  42.0    Man    No
# 43     Tech articles written by other developers;Indu...  43.0    Man    No
# 44     Tech articles written by other developers;Cour...  62.0    Man    No
# 45     Tech articles written by other developers;Indu...  37.0    Man    No
# 46     Tech articles written by other developers;Tech...  45.0    Man    No
# 49     Tech articles written by other developers;Tech...  23.0    Man    No
# 52     Tech articles written by other developers;Indu...  18.0    Man    No
# 55     Tech articles written by other developers;Indu...  33.0    Man    No
# 57                                                   NaN  47.0    Man    No
# 59     Industry news about technologies you're intere...  27.0    Man    No
# 60     Tech articles written by other developers;Indu...  34.0    Man    No
# 64                                                   NaN  21.0    Man    No
# 65                                                   NaN   NaN    NaN   NaN
# 67     Tech articles written by other developers;Indu...  29.0    Man    No
# 69     Tech articles written by other developers;Indu...  42.0    Man    No
# 74          Courses on technologies you're interested in  27.0  Woman    No
# 75     Tech articles written by other developers;Indu...  32.0    Man    No
# ...                                                  ...   ...    ...   ...
# 88273  Tech articles written by other developers;Indu...  26.0    Man    No
# 88274  Industry news about technologies you're intere...   NaN    Man    No
# 88275                                                NaN  30.0    Man    No
# 88278                                                NaN  27.0    Man    No
# 88281  Tech articles written by other developers;Cour...  26.0    Man    No
# 88282  Tech articles written by other developers;Tech...  43.0    Man    No
# 88283                                                NaN  40.0    Man    No
# 88287  Tech articles written by other developers;Indu...  30.0    Man    No
# 88289  Tech articles written by other developers;Indu...  34.0    Man    No
# 88290          Tech articles written by other developers  27.0    Man    No
# 88291  Industry news about technologies you're intere...  22.0    Man    No
# 88293  Tech articles written by other developers;Indu...  32.0    Man    No
# 88298  Tech articles written by other developers;Indu...  34.0    Man    No
# 88301  Tech articles written by other developers;Indu...  27.0    Man    No
# 88302          Tech articles written by other developers   NaN    Man    No
# 88303  Industry news about technologies you're intere...  27.0    Man    No
# 88304  Tech articles written by other developers;Indu...   NaN    NaN   NaN
# 88305  Tech articles written by other developers;Indu...  40.0    Man    No
# 88306  Industry news about technologies you're intere...  24.0    Man    No
# 88309                                                NaN  41.0    Man    No
# 88312                                                NaN  36.0    Man    No
# 88315  Tech articles written by other developers;Indu...  30.0    Man    No
# 88316          Tech articles written by other developers  30.0    Man    No
# 88319  Tech articles written by other developers;Cour...   NaN    Man    No
# 88320  Tech articles written by other developers;Indu...  37.0    Man    No
# 88321                                                NaN  26.0    Man    No
# 88323                                                NaN  23.0    Man    No
# 88324  Tech articles written by other developers;Cour...  48.0    Man    No
# 88325  Tech articles written by other developers;Indu...  26.0    Man    No
# 88327                                                NaN   NaN    NaN   NaN
#
#                      Sexuality  \
# 3      Straight / Heterosexual
# 5      Straight / Heterosexual
# 9                          NaN
# 12     Straight / Heterosexual
# 13     Straight / Heterosexual
# 15     Straight / Heterosexual
# 21     Straight / Heterosexual
# 22     Straight / Heterosexual
# 25              Gay or Lesbian
# 28     Straight / Heterosexual
# 31     Straight / Heterosexual
# 34     Straight / Heterosexual
# 35     Straight / Heterosexual
# 38                    Bisexual
# 43     Straight / Heterosexual
# 44     Straight / Heterosexual
# 45     Straight / Heterosexual
# 46     Straight / Heterosexual
# 49                         NaN
# 52     Straight / Heterosexual
# 55     Straight / Heterosexual
# 57     Straight / Heterosexual
# 59                    Bisexual
# 60     Straight / Heterosexual
# 64                         NaN
# 65                         NaN
# 67     Straight / Heterosexual
# 69     Straight / Heterosexual
# 74     Straight / Heterosexual
# 75     Straight / Heterosexual
# ...                        ...
# 88273  Straight / Heterosexual
# 88274  Straight / Heterosexual
# 88275  Straight / Heterosexual
# 88278  Straight / Heterosexual
# 88281  Straight / Heterosexual
# 88282  Straight / Heterosexual
# 88283  Straight / Heterosexual
# 88287  Straight / Heterosexual
# 88289  Straight / Heterosexual
# 88290  Straight / Heterosexual
# 88291  Straight / Heterosexual
# 88293           Gay or Lesbian
# 88298  Straight / Heterosexual
# 88301  Straight / Heterosexual
# 88302  Straight / Heterosexual
# 88303  Straight / Heterosexual
# 88304                      NaN
# 88305  Straight / Heterosexual
# 88306                      NaN
# 88309                      NaN
# 88312           Gay or Lesbian
# 88315                 Bisexual
# 88316                      NaN
# 88319                      NaN
# 88320           Gay or Lesbian
# 88321  Straight / Heterosexual
# 88323  Straight / Heterosexual
# 88324  Straight / Heterosexual
# 88325  Straight / Heterosexual
# 88327                      NaN
#
#                                                Ethnicity  Dependents  \
# 3                           White or of European descent          No
# 5                                             East Asian          No
# 9                                                    NaN         Yes
# 12                          White or of European descent         Yes
# 13                          White or of European descent          No
# 15                          White or of European descent          No
# 21                          White or of European descent         Yes
# 22                           Black or of African descent          No
# 25                                                   NaN          No
# 28                          White or of European descent         Yes
# 31                          White or of European descent          No
# 34                           Black or of African descent          No
# 35                          White or of European descent          No
# 38                          White or of European descent          No
# 43                          White or of European descent         Yes
# 44                          White or of European descent          No
# 45                          White or of European descent          No
# 46                          White or of European descent         Yes
# 49                                           South Asian          No
# 52                          White or of European descent          No
# 55                                            East Asian         Yes
# 57                          White or of European descent         Yes
# 59                          White or of European descent          No
# 60                          White or of European descent          No
# 64                                                   NaN         Yes
# 65                                                   NaN         Yes
# 67                                           South Asian          No
# 69                                                   NaN         Yes
# 74                                                   NaN          No
# 75                          White or of European descent         Yes
# ...                                                  ...         ...
# 88273                                        South Asian         Yes
# 88274                       White or of European descent          No
# 88275                       White or of European descent          No
# 88278                       White or of European descent         Yes
# 88281                       White or of European descent          No
# 88282                       White or of European descent         Yes
# 88283                       White or of European descent         Yes
# 88287                       White or of European descent          No
# 88289  Hispanic or Latino/Latina;White or of European...          No
# 88290                       White or of European descent          No
# 88291                                        South Asian         Yes
# 88293                                         East Asian          No
# 88298                                        South Asian          No
# 88301  Hispanic or Latino/Latina;Native American, Pac...          No
# 88302                       White or of European descent         Yes
# 88303                       White or of European descent          No
# 88304                                                NaN         NaN
# 88305                          Hispanic or Latino/Latina         Yes
# 88306                       White or of European descent          No
# 88309                                                NaN         Yes
# 88312                       White or of European descent          No
# 88315                          Hispanic or Latino/Latina          No
# 88316                                        South Asian          No
# 88319                                                NaN         Yes
# 88320                       White or of European descent          No
# 88321                       White or of European descent          No
# 88323                       White or of European descent          No
# 88324                                        South Asian         Yes
# 88325                                        South Asian          No
# 88327                                                NaN         NaN
#
#                 SurveyLength                  SurveyEase
# 3      Appropriate in length                        Easy
# 5                   Too long  Neither easy nor difficult
# 9                   Too long                   Difficult
# 12     Appropriate in length                        Easy
# 13                 Too short                        Easy
# 15     Appropriate in length  Neither easy nor difficult
# 21     Appropriate in length                        Easy
# 22     Appropriate in length                        Easy
# 25     Appropriate in length                        Easy
# 28     Appropriate in length                        Easy
# 31     Appropriate in length  Neither easy nor difficult
# 34     Appropriate in length                        Easy
# 35                  Too long  Neither easy nor difficult
# 38     Appropriate in length                        Easy
# 43     Appropriate in length                        Easy
# 44     Appropriate in length  Neither easy nor difficult
# 45                  Too long  Neither easy nor difficult
# 46     Appropriate in length                        Easy
# 49                  Too long                        Easy
# 52     Appropriate in length                        Easy
# 55     Appropriate in length                        Easy
# 57                       NaN                        Easy
# 59                       NaN                         NaN
# 60     Appropriate in length                        Easy
# 64     Appropriate in length  Neither easy nor difficult
# 65                  Too long  Neither easy nor difficult
# 67     Appropriate in length                        Easy
# 69     Appropriate in length                        Easy
# 74                  Too long  Neither easy nor difficult
# 75                  Too long  Neither easy nor difficult
# ...                      ...                         ...
# 88273  Appropriate in length  Neither easy nor difficult
# 88274  Appropriate in length                        Easy
# 88275  Appropriate in length                        Easy
# 88278  Appropriate in length                        Easy
# 88281  Appropriate in length                        Easy
# 88282  Appropriate in length                        Easy
# 88283  Appropriate in length  Neither easy nor difficult
# 88287  Appropriate in length                        Easy
# 88289  Appropriate in length                        Easy
# 88290  Appropriate in length                        Easy
# 88291  Appropriate in length                        Easy
# 88293  Appropriate in length                        Easy
# 88298               Too long  Neither easy nor difficult
# 88301  Appropriate in length                        Easy
# 88302  Appropriate in length                        Easy
# 88303  Appropriate in length                        Easy
# 88304                    NaN                         NaN
# 88305               Too long  Neither easy nor difficult
# 88306               Too long  Neither easy nor difficult
# 88309               Too long  Neither easy nor difficult
# 88312  Appropriate in length                        Easy
# 88315  Appropriate in length                        Easy
# 88316               Too long  Neither easy nor difficult
# 88319                    NaN  Neither easy nor difficult
# 88320  Appropriate in length                        Easy
# 88321  Appropriate in length                        Easy
# 88323  Appropriate in length                        Easy
# 88324               Too long  Neither easy nor difficult
# 88325  Appropriate in length                        Easy
# 88327                    NaN                         NaN
#
# [37172 rows x 85 columns]

# %%
coi_df[['Country', 'CompTotal', 'JobSat', 'CareerSat']].groupby('Country').mean()
# Out:
#                    CompTotal    JobSat  CareerSat
# Country
# Canada          9.001689e+04  2.887043   3.137689
# China           9.961071e+04  2.000000   2.210066
# Germany         4.893753e+04  2.709187   2.938754
# India           5.068869e+07  2.437215   2.717139
# United Kingdom  1.683873e+05  2.782001   3.060818
# United States   1.332889e+12  2.889230   3.215970

# %%
coi_df['CurrencySymbol'].value_counts().head(6)
# Out:
# USD    17828
# INR     6570
# GBP     4810
# EUR     4738
# CAD     2661
# CNY      422
# Name: CurrencySymbol, dtype: int64

# %%
def any_currency_to_usd(currency,money):
    if currency == 'INR':
        return 0.014 * money
    elif currency == 'GBP':
        return 1.24 * money
    elif currency == 'EUR':
        return 1.11 * money
    elif currency == 'CAD':
        return 0.76 * money
    elif currency == 'CNY':
        return 0.15 * money
    else:
        return money

# %%
currency_of_interest = ['USD','INR','GBP','EUR','CAD','CNY']

# %%
coi_df_curroi_df = coi_df[coi_df['CurrencySymbol'].map(lambda x: x in currency_of_interest)]

# %%
coi_df_curroi_df['CurrencySymbol']
# Out:
# 3        USD
# 5        CAD
# 9        INR
# 12       USD
# 13       EUR
# 15       GBP
# 21       USD
# 22       USD
# 25       USD
# 28       USD
# 31       USD
# 34       USD
# 35       EUR
# 38       USD
# 43       EUR
# 44       USD
# 45       USD
# 46       USD
# 49       INR
# 52       USD
# 55       CNY
# 57       USD
# 59       USD
# 60       USD
# 64       INR
# 65       EUR
# 67       INR
# 69       USD
# 74       INR
# 75       GBP
#         ...
# 88266    USD
# 88273    INR
# 88274    USD
# 88275    USD
# 88278    USD
# 88281    GBP
# 88282    USD
# 88283    USD
# 88287    USD
# 88289    CAD
# 88290    USD
# 88291    INR
# 88293    CAD
# 88298    USD
# 88301    USD
# 88302    CAD
# 88303    USD
# 88305    USD
# 88306    CAD
# 88309    EUR
# 88312    USD
# 88315    EUR
# 88316    INR
# 88319    INR
# 88320    CAD
# 88321    USD
# 88323    USD
# 88324    USD
# 88325    USD
# 88327    USD
# Name: CurrencySymbol, Length: 37029, dtype: object

# %%
coi_df_curroi_df.CompTotal = coi_df_curroi_df.apply(lambda x: any_currency_to_usd(x.CurrencySymbol, x.CompTotal), axis=1)
# Out:
# /Users/xweng/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
coi_df_curroi_df = coi_df_curroi_df.dropna(subset=['CompTotal'])

# %%
coi_df_curroi_df[['Country', 'CompTotal', 'JobSat', 'CareerSat']].groupby('Country').median()
# Out:
#                 CompTotal  JobSat  CareerSat
# Country
# Canada            63080.0       3          3
# China              2775.0       2          2
# Germany           54390.0       3          3
# India              5943.0       3          3
# United Kingdom    55800.0       3          3
# United States    102000.0       3          4

# %%
coi_df_curroi_df[['Country', 'CompTotal', 'JobSat', 'CareerSat']].groupby('Country').mean()
# Out:
#                    CompTotal    JobSat  CareerSat
# Country
# Canada          6.791546e+04  2.898583   3.167848
# China           1.508739e+04  1.946721   2.118852
# Germany         4.730581e+04  2.699868   2.940927
# India           1.279799e+04  2.375814   2.695043
# United Kingdom  6.286909e+04  2.787946   3.085317
# United States   1.333511e+12  2.891052   3.236898

# %%
def cat_comp_to_level(comp):
    if comp < 50000:
        return 'less than 50K usd'
    elif comp >= 50000 and comp <100000:
        return 'between 50K and 100K'
    elif comp >= 100000 and comp < 200000:
        return 'between 100K and 200K'
    else:
        return 'more than 200K'

# %%
show_distribution_of_income('India',coi_df_curroi_df)
# Out:
# ('India',
#  array(['less than 50K usd', 'less than 50K usd', 'less than 50K usd', ...,
#         'less than 50K usd', 'less than 50K usd', 'less than 50K usd'],
#        dtype=object))

# %%
income_level_list = []

# %%
for country in countries_of_interest:
    income_level_list.append(show_distribution_of_income(country,coi_df_curroi_df))

# %%
for i in income_level_list:
    print(len(i[1]))
# Out:
# 14998
# 3994
# 3775
# 4032
# 2258
# 244

# %%
cdict = dict(zip(np.unique(['less than 50K usd','between 50K and 100K','between 100K and 200K','more than 200K']),cm.tab10.colors))

# %%
income_level_dict = dict(income_level_list)

# %%
counter_income_level = {}

# %%
for country,levels in income_level_list:
        counter_income_level[country]=dict([(level,num/sum(Counter(levels).values())) for level,num in Counter(levels).items()])

# %%
fig, axes = plt.subplots(nrows=3, ncols=2,figsize=(30,30))
counter_income_level_iter = iter(counter_income_level.items())
for i in range(3):
    for j in range(2):
        current_country,current_stats = next(counter_income_level_iter)
        current_stats = current_stats.items()
        current_stats = sorted(current_stats)
        axes[i, j].set_title(current_country,fontsize=25)
        axes[i, j].pie([i[1] for i in current_stats],labels=[i[0] for i in current_stats], autopct='%1.1f%%', shadow=True,textprops={'fontsize': 25})

# %%
the_usa_df = coi_df_curroi_df[coi_df_curroi_df.Country=='United States'][['Country', 'CompTotal', 'JobSat', 'CareerSat','SocialMedia']]

# %%
the_usa_df_without_comp_na = the_usa_df.dropna(subset=['CompTotal'])

# %%
the_usa_df_without_comp_na
# Out:
#              Country  CompTotal  JobSat  CareerSat               SocialMedia
# 3      United States    61000.0       3          4                    Reddit
# 12     United States    90000.0       4          4                   Twitter
# 21     United States   103000.0       0          3                 Instagram
# 22     United States    69000.0       3          3                    Reddit
# 25     United States   114000.0       4          4  I don't use social media
# 28     United States     2000.0       3          4                    Reddit
# 31     United States    22000.0       3          3                   YouTube
# 34     United States    80000.0       0          3                 Instagram
# 38     United States   156000.0       4          4                    Reddit
# 44     United States   175000.0       3          3                  Facebook
# 46     United States   187000.0       4          4                 Instagram
# 52     United States    47300.0       3          3                 Instagram
# 57     United States   113000.0       4          4  I don't use social media
# 59     United States   107000.0       2          3                   Twitter
# 60     United States    66000.0       4          4                    Reddit
# 69     United States    75000.0       1          1                   YouTube
# 76     United States   100000.0       4          4                       NaN
# 94     United States   110000.0       4          4                    Reddit
# 96     United States    66750.0       3          1                  Facebook
# 101    United States    67800.0       3          3  I don't use social media
# 104    United States    45000.0       4          4                  Facebook
# 105    United States   160000.0       4          4                    Reddit
# 107    United States   140000.0       0          1  I don't use social media
# 109    United States   100000.0       3          3                    Reddit
# 116    United States    26000.0       1          4                  Facebook
# 125    United States    60000.0       3          3                  WhatsApp
# 126    United States   106000.0       4          4                   Twitter
# 128    United States    62000.0       3          4                   YouTube
# 131    United States    83200.0       4          3                  Facebook
# 137    United States    70000.0       4          3                    Reddit
# ...              ...        ...     ...        ...                       ...
# 88169  United States    82625.0       3          3                    Reddit
# 88177  United States    67000.0       4          4                    Reddit
# 88183  United States   120000.0       0          0                   Twitter
# 88192  United States    95000.0       4          4                  Facebook
# 88199  United States    71000.0       1          1                   Twitter
# 88208  United States   124000.0       3          3                    Reddit
# 88212  United States    80000.0       4          3                  LinkedIn
# 88214  United States   120000.0       4          4                    Reddit
# 88227  United States    79500.0       3          3                   Twitter
# 88239  United States     1040.0       3          3                    Reddit
# 88244  United States   225000.0       2          3                   YouTube
# 88246  United States   105000.0       3          3                  Facebook
# 88264  United States   130000.0       2          3                 Instagram
# 88266  United States    85000.0       3          4                    Reddit
# 88274  United States    70000.0       1          1                   Twitter
# 88275  United States   110000.0       4          4  I don't use social media
# 88278  United States    65000.0       4          4                   Twitter
# 88282  United States   120000.0       2          3                   Twitter
# 88283  United States   230000.0       4          4                  LinkedIn
# 88287  United States    95000.0       4          3                 Instagram
# 88290  United States   111000.0       4          4  I don't use social media
# 88298  United States   120000.0       2          2                  WhatsApp
# 88301  United States   110000.0       3          3                  Facebook
# 88303  United States    80000.0       3          3  I don't use social media
# 88305  United States    45000.0       1          4                   YouTube
# 88312  United States   120000.0       4          4                   Twitter
# 88321  United States   185000.0       4          4                    Reddit
# 88323  United States   180000.0       3          4                    Reddit
# 88324  United States   239000.0       4          4                  Facebook
# 88325  United States   130000.0       4          4                   Twitter
#
# [14998 rows x 5 columns]

# %%
the_usa_df_without_comp_na.groupby('SocialMedia').mean()
# Out:
#                              CompTotal  JobSat  CareerSat
# SocialMedia
# Facebook                  1.209000e+05     3.0        3.0
# I don't use social media  8.417509e+12     3.0        3.0
# Instagram                 1.127780e+05     3.0        3.0
# LinkedIn                  1.382650e+05     3.0        3.0
# Reddit                    1.093580e+05     3.0        3.0
# Snapchat                  9.007200e+04     3.0        3.0
# Twitter                   1.259620e+05     3.0        3.0
# VK ВКонта́кте             7.970000e+04     3.0        2.0
# WeChat 微信                 1.557560e+05     3.0        3.0
# Weibo 新浪微博                9.500000e+04     2.0        2.0
# WhatsApp                  2.566727e+06     3.0        3.0
# YouTube                   6.506181e+12     3.0        3.0
